# %%
from collections import defaultdict
import random
import numpy as np
import matplotlib.pyplot as plt

import time
from tqdm import tqdm 
import multiprocessing

# import gymnasium as gym
import gym
import gym_examples
from gym.wrappers import FlattenObservation

from algos import *
from utils import *

# %%
random.seed(123)
np.random.seed(123)
tdqm_disable = True

# params
env_id = "gym_examples/GridWorld-v1"
gridworld_size = 3
max_steps = 20
gamma = 0.95

num_trials = 1000
num_episodes_train = 10000
num_episodes_eval = 100

lr_sched_type = "linear"
lr_sched_fn = create_lr_sched_fn(lr_sched_type)

max_eps = 1.0
min_eps = 0.05
decay_rate = 0.0005
eps_sched_type = "poly"
eps_sched_fn = create_eps_sched_fn(eps_sched_type, min_eps, max_eps, decay_rate)

haver_const = 20.0
est_name = "haver" 
q_algo_name = "haver_q_learning"
q_algo = create_q_algo(q_algo_name)

# create gym env
env = gym.make(env_id, size=gridworld_size)
env_wrapped = FlattenObservation(env)
num_actions = env_wrapped.action_space.n
# print(f"num_actions = {num_actions}")
# print(env_wrapped.reset())
# stop

manager = multiprocessing.Manager()
episode_lengths_list = manager.list()
episode_rewards_list = manager.list()
episode_start_vals_list = manager.list()

def run_trial(i_trial, args):

    random.seed(10000+i_trial)
    np.random.seed(10000+i_trial)

    env = gym.make(env_id, size=gridworld_size)
    env_wrapped = FlattenObservation(env)
    # env_wrapped.reset(seed=10000+i_trial)

    lr_sched_fn = create_lr_sched_fn(lr_sched_type)
    eps_sched_fn = create_eps_sched_fn(eps_sched_type, min_eps, max_eps, decay_rate)
    q_algo = create_q_algo(args["algo_name"])

    # init Q_table, Q_nvisits
    Q_table = defaultdict(lambda: np.zeros(num_actions))
    Q_nvisits = defaultdict(lambda: np.zeros(num_actions))
    Q_table, stats = q_algo(
        env_wrapped, Q_table, Q_nvisits, num_episodes_train, max_steps,
        gamma, lr_sched_fn, eps_sched_fn, tdqm_disable, args)

    episode_lengths, episode_rewards, episode_start_vals= zip(*stats)
    episode_lengths_list.append(episode_lengths)
    episode_rewards_list.append(episode_rewards)
    episode_start_vals_list.append(episode_start_vals)

episode_lengths_mean_dict = defaultdict()
episode_rewards_mean_dict = defaultdict()
episode_start_vals_mean_dict = defaultdict()

args = dict()
pool = multiprocessing.Pool()

algo_names = ["haver2", "haver", "double", "max", "avg"]
for algo_name in algo_names:
    start_time = time.time()
    print(f"\n-> algo_name = {algo_name}")
    args["algo_name"] = algo_name
    if algo_name in ["haver", "haver2"]:
        print(f"haver_const = {haver_const}")
        args["haver_const"] =  haver_const
         
    pool.starmap(run_trial, [(i, args) for i in range(num_trials)])

    episode_lengths_ary = np.hstack([episode_lengths_list])
    episode_rewards_ary = np.hstack([episode_rewards_list])
    episode_start_vals_ary = np.hstack([episode_start_vals_list])

    episode_lengths_mean_dict[algo_name] = np.mean(episode_lengths_ary, 0)
    episode_rewards_mean_dict[algo_name] = np.mean(episode_rewards_ary, 0)
    episode_start_vals_mean_dict[algo_name] = np.mean(episode_start_vals_ary, 0)
    print(f"last_episode_length = {episode_lengths_mean_dict[algo_name][-1]}")
    print(f"last_episode_reward_per_step = {episode_rewards_mean_dict[algo_name][-1]:.4f}")
    print(f"last_episode_estim_start_val = {episode_start_vals_mean_dict[algo_name][-1]:.4f}")
    
    episode_lengths_list[:] = []
    episode_rewards_list[:] = []
    episode_start_vals_list[:] = []
    
    end_time = time.time()
    print(f"it takes {end_time-start_time:0.4f}")
# Out:
# -> algo_name = haver2
# haver_const = 20.0
# last_episode_length = 5.144
# last_episode_reward_per_step = 0.3831
# last_episode_estim_start_val = -1.7848
# it takes 1058.3434
#
# -> algo_name = haver
# haver_const = 20.0
# last_episode_length = 5.144
# last_episode_reward_per_step = 0.3831
# last_episode_estim_start_val = -1.7848
# it takes 1055.1618
#
# -> algo_name = double
# Process ForkPoolWorker-21:
# Process ForkPoolWorker-18:
# Process ForkPoolWorker-22:
# Process ForkPoolWorker-20:
# Process ForkPoolWorker-17:
# Process ForkPoolWorker-25:
# Process ForkPoolWorker-16:
# Process ForkPoolWorker-19:
# Process ForkPoolWorker-23:
# Process ForkPoolWorker-24:
# Process ForkPoolWorker-15:
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_1449150/762591058.py in <module>
#      81         args["haver_const"] =  haver_const
#      82
# ---> 83     pool.starmap(run_trial, [(i, args) for i in range(num_trials)])
#      84
#      85     episode_lengths_ary = np.hstack([episode_lengths_list])
#
# ~/miniconda3/envs/tnn1/lib/python3.7/multiprocessing/pool.py in starmap(self, func, iterable, chunksize)
#     274         `func` and (a, b) becomes func(a, b).
#     275         '''
# --> 276         return self._map_async(func, iterable, starmapstar, chunksize).get()
#     277
#     278     def starmap_async(self, func, iterable, chunksize=None, callback=None,
#
# ~/miniconda3/envs/tnn1/lib/python3.7/multiprocessing/pool.py in get(self, timeout)
#     649
#     650     def get(self, timeout=None):
# --> 651         self.wait(timeout)
#     652         if not self.ready():
#     653             raise TimeoutError
#
# ~/miniconda3/envs/tnn1/lib/python3.7/multiprocessing/pool.py in wait(self, timeout)
#     646
#     647     def wait(self, timeout=None):
# --> 648         self._event.wait(timeout)
#     649
#     650     def get(self, timeout=None):
#
# ~/miniconda3/envs/tnn1/lib/python3.7/threading.py in wait(self, timeout)
#     550             signaled = self._flag
#     551             if not signaled:
# --> 552                 signaled = self._cond.wait(timeout)
#     553             return signaled
#     554
#
# ~/miniconda3/envs/tnn1/lib/python3.7/threading.py in wait(self, timeout)
#     294         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     295             if timeout is None:
# --> 296                 waiter.acquire()
#     297                 gotit = True
#     298             else:
#
# KeyboardInterrupt:
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/multiprocessing/pool.py", line 47, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
# Traceback (most recent call last):
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/multiprocessing/pool.py", line 47, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/multiprocessing/pool.py", line 47, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/tmp/ipykernel_1449150/762591058.py", line 60, in run_trial
#     gamma, lr_sched_fn, eps_sched_fn, tdqm_disable, args)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/multiprocessing/pool.py", line 47, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/multiprocessing/pool.py", line 47, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/multiprocessing/pool.py", line 47, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/multiprocessing/pool.py", line 47, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/tmp/ipykernel_1449150/762591058.py", line 60, in run_trial
#     gamma, lr_sched_fn, eps_sched_fn, tdqm_disable, args)
#   File "/tmp/ipykernel_1449150/762591058.py", line 60, in run_trial
#     gamma, lr_sched_fn, eps_sched_fn, tdqm_disable, args)
#   File "/tmp/ipykernel_1449150/762591058.py", line 60, in run_trial
#     gamma, lr_sched_fn, eps_sched_fn, tdqm_disable, args)
#   File "/tmp/ipykernel_1449150/762591058.py", line 60, in run_trial
#     gamma, lr_sched_fn, eps_sched_fn, tdqm_disable, args)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/multiprocessing/pool.py", line 47, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/data/tnn/10_School/02_ResearchProjects/01_MCTS_Analysis/02_qlearning/double_qlearning_gridworld/algos.py", line 194, in double_q_learning
#     new_state = f"{new_state}"
#   File "/tmp/ipykernel_1449150/762591058.py", line 60, in run_trial
#     gamma, lr_sched_fn, eps_sched_fn, tdqm_disable, args)
#   File "/data/tnn/10_School/02_ResearchProjects/01_MCTS_Analysis/02_qlearning/double_qlearning_gridworld/algos.py", line 188, in double_q_learning
#     nvisits = np.sum(Q_nvisits[state]) + 1
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/data/tnn/10_School/02_ResearchProjects/01_MCTS_Analysis/02_qlearning/double_qlearning_gridworld/algos.py", line 194, in double_q_learning
#     new_state = f"{new_state}"
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/data/tnn/10_School/02_ResearchProjects/01_MCTS_Analysis/02_qlearning/double_qlearning_gridworld/algos.py", line 192, in double_q_learning
#     new_state, reward, terminated, truncated, info = env.step(action)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/tmp/ipykernel_1449150/762591058.py", line 60, in run_trial
#     gamma, lr_sched_fn, eps_sched_fn, tdqm_disable, args)
#   File "/tmp/ipykernel_1449150/762591058.py", line 60, in run_trial
#     gamma, lr_sched_fn, eps_sched_fn, tdqm_disable, args)
#   File "/data/tnn/10_School/02_ResearchProjects/01_MCTS_Analysis/02_qlearning/double_qlearning_gridworld/algos.py", line 181, in double_q_learning
#     state, info = env.reset()
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/numpy/core/arrayprint.py", line 1551, in _array_str_implementation
#     return array2string(a, max_line_width, precision, suppress_small, ' ', "")
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/multiprocessing/pool.py", line 47, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/data/tnn/10_School/02_ResearchProjects/01_MCTS_Analysis/02_qlearning/double_qlearning_gridworld/algos.py", line 190, in double_q_learning
#     action = eps_greedy_policy(Q_table, state, eps)
#   File "<__array_function__ internals>", line 6, in sum
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/data/tnn/10_School/02_ResearchProjects/01_MCTS_Analysis/02_qlearning/double_qlearning_gridworld/algos.py", line 192, in double_q_learning
#     new_state, reward, terminated, truncated, info = env.step(action)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/multiprocessing/pool.py", line 47, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/numpy/core/arrayprint.py", line 1551, in _array_str_implementation
#     return array2string(a, max_line_width, precision, suppress_small, ' ', "")
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/multiprocessing/pool.py", line 47, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/tmp/ipykernel_1449150/762591058.py", line 60, in run_trial
#     gamma, lr_sched_fn, eps_sched_fn, tdqm_disable, args)
#   File "/data/tnn/10_School/02_ResearchProjects/01_MCTS_Analysis/02_qlearning/double_qlearning_gridworld/algos.py", line 47, in eps_greedy_policy
#     action_probs = eps*np.ones(num_actions)/num_actions
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/numpy/core/arrayprint.py", line 698, in array2string
#     return _array2string(a, options, separator, prefix)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/gym/core.py", line 380, in reset
#     return self.observation(obs), info
#   File "/data/tnn/10_School/02_ResearchProjects/01_MCTS_Analysis/02_qlearning/double_qlearning_gridworld/algos.py", line 190, in double_q_learning
#     action = eps_greedy_policy(Q_table, state, eps)
#   File "/tmp/ipykernel_1449150/762591058.py", line 60, in run_trial
#     gamma, lr_sched_fn, eps_sched_fn, tdqm_disable, args)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/numpy/core/arrayprint.py", line 698, in array2string
#     return _array2string(a, options, separator, prefix)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/gym/core.py", line 384, in step
#     observation, reward, terminated, truncated, info = self.env.step(action)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/numpy/core/fromnumeric.py", line 2260, in sum
#     initial=initial, where=where)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/gym/wrappers/flatten_observation.py", line 40, in observation
#     return spaces.flatten(self.env.observation_space, observation)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/gym/core.py", line 384, in step
#     observation, reward, terminated, truncated, info = self.env.step(action)
# KeyboardInterrupt
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/numpy/core/arrayprint.py", line 470, in wrapper
#     key = id(self), get_ident()
#   File "/tmp/ipykernel_1449150/762591058.py", line 60, in run_trial
#     gamma, lr_sched_fn, eps_sched_fn, tdqm_disable, args)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/gym/wrappers/order_enforcing.py", line 37, in step
#     return self.env.step(action)
# KeyboardInterrupt
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/numpy/core/fromnumeric.py", line 86, in _wrapreduction
#     return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#   File "/data/tnn/10_School/02_ResearchProjects/01_MCTS_Analysis/02_qlearning/double_qlearning_gridworld/algos.py", line 192, in double_q_learning
#     new_state, reward, terminated, truncated, info = env.step(action)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/numpy/core/arrayprint.py", line 475, in wrapper
#     return f(self, *args, **kwargs)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/functools.py", line 840, in wrapper
#     return dispatch(args[0].__class__)(*args, **kw)
#   File "/data/tnn/10_School/02_ResearchProjects/01_MCTS_Analysis/02_qlearning/double_qlearning_gridworld/algos.py", line 49, in eps_greedy_policy
#     eps_greedy_action = np.random.choice(num_actions, 1, p=action_probs)[0]
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/gym/wrappers/order_enforcing.py", line 37, in step
#     return self.env.step(action)
#   File "/data/tnn/10_School/02_ResearchProjects/01_MCTS_Analysis/02_qlearning/double_qlearning_gridworld/algos.py", line 190, in double_q_learning
#     action = eps_greedy_policy(Q_table, state, eps)
#   File "/data/tnn/10_School/02_ResearchProjects/01_MCTS_Analysis/02_qlearning/double_qlearning_gridworld/algos.py", line 192, in double_q_learning
#     new_state, reward, terminated, truncated, info = env.step(action)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/gym/wrappers/env_checker.py", line 39, in step
#     return self.env.step(action)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/gym/core.py", line 384, in step
#     observation, reward, terminated, truncated, info = self.env.step(action)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/functools.py", line 791, in dispatch
#     if cache_token != current_token:
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/gym/core.py", line 384, in step
#     observation, reward, terminated, truncated, info = self.env.step(action)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/numpy/core/arrayprint.py", line 510, in _array2string
#     summary_insert, options['legacy'])
#   File "/data/tnn/10_School/02_ResearchProjects/01_MCTS_Analysis/02_qlearning/double_qlearning_gridworld/algos.py", line 47, in eps_greedy_policy
#     action_probs = eps*np.ones(num_actions)/num_actions
# KeyboardInterrupt
#   File "mtrand.pyx", line 922, in numpy.random.mtrand.RandomState.choice
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/gym/wrappers/order_enforcing.py", line 37, in step
#     return self.env.step(action)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/gym/wrappers/env_checker.py", line 39, in step
#     return self.env.step(action)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/gym/wrappers/order_enforcing.py", line 37, in step
#     return self.env.step(action)
#   File "/home/tnn/Downloads/Packages/gym-examples/gym_examples/envs/grid_world.py", line 243, in step
#     self._agent_location + direction, 0, self.size-1)
# KeyboardInterrupt
# KeyboardInterrupt
# Process ForkPoolWorker-26:
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/numpy/core/numerictypes.py", line 358, in issubdtype
#     @set_module('numpy')
#   File "<__array_function__ internals>", line 6, in clip
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/gym/wrappers/env_checker.py", line 39, in step
#     return self.env.step(action)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/gym/wrappers/env_checker.py", line 39, in step
#     return self.env.step(action)
# KeyboardInterrupt
#   File "/home/tnn/Downloads/Packages/gym-examples/gym_examples/envs/grid_world.py", line 243, in step
#     self._agent_location + direction, 0, self.size-1)
#   File "/home/tnn/Downloads/Packages/gym-examples/gym_examples/envs/grid_world.py", line 256, in step
#     info = self._get_info()
#   File "<__array_function__ internals>", line 6, in clip
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/numpy/core/fromnumeric.py", line 2115, in clip
#     return _wrapfunc(a, 'clip', a_min, a_max, out=out, **kwargs)
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/home/tnn/Downloads/Packages/gym-examples/gym_examples/envs/grid_world.py", line 243, in step
#     self._agent_location + direction, 0, self.size-1)
#   File "/home/tnn/Downloads/Packages/gym-examples/gym_examples/envs/grid_world.py", line 340, in _get_info
#     self._agent_location - self._target_location, ord=1)}
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/numpy/core/fromnumeric.py", line 2115, in clip
#     return _wrapfunc(a, 'clip', a_min, a_max, out=out, **kwargs)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# KeyboardInterrupt
#   File "<__array_function__ internals>", line 4, in norm
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/numpy/core/fromnumeric.py", line 57, in _wrapfunc
#     return bound(*args, **kwds)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/numpy/core/fromnumeric.py", line 57, in _wrapfunc
#     return bound(*args, **kwds)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/numpy/core/_methods.py", line 160, in _clip
#     um.clip, a, min, max, out=out, casting=casting, **kwargs)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
# KeyboardInterrupt
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/numpy/core/_methods.py", line 137, in _clip
#     if _clip_dep_is_scalar_nan(max):
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/numpy/core/_methods.py", line 113, in _clip_dep_invoke_with_casting
#     return ufunc(*args, out=out, **kwargs)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/numpy/core/_methods.py", line 93, in _clip_dep_is_scalar_nan
#     from numpy.core.fromnumeric import ndim
# KeyboardInterrupt
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/multiprocessing/pool.py", line 47, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "<frozen importlib._bootstrap>", line 1009, in _handle_fromlist
#   File "/tmp/ipykernel_1449150/762591058.py", line 60, in run_trial
#     gamma, lr_sched_fn, eps_sched_fn, tdqm_disable, args)
# KeyboardInterrupt
#   File "/data/tnn/10_School/02_ResearchProjects/01_MCTS_Analysis/02_qlearning/double_qlearning_gridworld/algos.py", line 192, in double_q_learning
#     new_state, reward, terminated, truncated, info = env.step(action)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/gym/core.py", line 385, in step
#     return self.observation(observation), reward, terminated, truncated, info
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/gym/wrappers/flatten_observation.py", line 40, in observation
#     return spaces.flatten(self.env.observation_space, observation)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/functools.py", line 840, in wrapper
#     return dispatch(args[0].__class__)(*args, **kw)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/functools.py", line 795, in dispatch
#     impl = dispatch_cache[cls]
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/weakref.py", line 396, in __getitem__
#     return self.data[ref(key)]
# KeyboardInterrupt

# %%
# for i_trial in range(num_trials):
#     last_episode_length = episode_lengths_list[i_trial,-1]
#     if episode_lengths_list[i_trial,-1] > 4:
#         print(i_trial, last_episode_length)
print(episode_lengths_ary[:100,-1])

# %%
fig, axes = fig, axes = plt.subplots(
        nrows=3, ncols=1, sharex=True, sharey=False, figsize=(8,8))
# axes = [axes]

x_ary = np.linspace(0, num_episodes_train-1, num=100, dtype=np.int32)
algo_names = ["haver", "double", "avg", "max"]
for algo_name in algo_names:
    y_ary = running_avg(episode_rewards_mean_dict[algo_name][x_ary], 10)
    axes[0].plot(
        x_ary, y_ary, label=algo_name)
    # axes[0].plot(x_ary, episode_rewards_mean[x_ary], label=algo_name)
    axes[1].plot(x_ary, episode_start_vals_mean_dict[algo_name][x_ary], label=algo_name)
    axes[2].plot(x_ary, episode_lengths_mean_dict[algo_name][x_ary], label=algo_name)

axes[0].set_title("reward_per_step")
axes[1].set_title("estim_qval_start_state")
axes[2].set_title("episode_length")
axes[0].legend()
axes[1].legend()
axes[2].legend()
plt.show()
