# %%
using Plots
plotly()

plot(rand(10),rand(10))

# %%
for i in 1:4
    println(i)
end
# Out:
# 1
# 2
# 3
# 4

# %%
using Random
using Statistics

# %%
rng = MersenneTwister(1234);
a = rand(rng, 4)
print(a)
b = (a.*2.0).-2.0
println(b)
# Out:
# [0.5908446386657102, 0.7667970365022592, 0.5662374165061859, 0.4600853424625171][-0.8183107226685795, -0.46640592699548167, -0.8675251669876283, -1.0798293150749658]
